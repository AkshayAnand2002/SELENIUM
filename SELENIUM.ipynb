# %%
from selenium import webdriver
PATH="C:\chromedriver.exe"#path where driver is located in computer.
driver= webdriver.Chrome(PATH)#using chrome we use the webdriver.
driver.get("https://www.google.com/")
#driver.close()#to close the driver.
#above does closing of current tab only.
#if we want to close entire browser and not just one tab i.e current tab then we use driver.quit()
print(driver.title)#to get title of the webpage we give in driver.get()
driver.quit()

# %%
#CLINKING ON A BUTTON
rom selenium import webdriver
website='https://www.adamchoi.co.uk/overs/detailed'
path="C:\chromedriver.exe"
driver=webdriver.Chrome(path)
driver.get(website)
#To locate any element of website we use inspect and for selecting a particular element abd get its website code 
#we use the arrow on top-left corner.
#User CTRL+F to write X-path to locate a particular element by class name or id or attribute etc.
#Since All matches button on the website does not have any id we select it on any of its unique features.
#<label class="btn btn-sm btn-primary ng-untouched ng-valid ng-not-empty active ng-dirty ng-valid-parse" data-ng-model="hasc.$scope.doShowSplit" data-btn-radio="false" analytics-on="click" analytics-event="All matches" analytics-category="Detailed pages filters" analytics-label="Home Away Selector">All matches</label>
#above is html code on site we used analytics event to select it.
# used x-path for above is //label[@analytics-event="All matches"].
all_matches_button=driver.find_element_by_xpath('//label[@analytics-event="All matches"]')
#note-if x-path expression has double quotes use single quotes outside as in above line.
all_matches_button.click()
#driver.quit()

# %%
#EXTRACTING DATA FROM TABLE.
#for Table using using same method of using arrow and locating a row together using elements.
#eg for selecting first row fully we have html code in site as--
#<tr data-ng-repeat="match in ::dtc.$scope.matches" data-ng-class=":refreshHighlight:match.result === ' - ' ? 'upcoming' : dtc.getHighlight(match, match.homeTeam === dtc.$scope.teamname ? 'home' : 'away')" class="ng-scope isNotHighlightedRow"><td style="width:25%;" class="ng-binding">13-08-2021</td><td style="width:31%;" data-ng-style="::{'font-weight' : match.homeTeam === dtc.$scope.teamname ? 'bold' : ''}" class="ng-binding">Brentford</td><td style="width:13%;" class="ng-binding">2 - 0</td><td style="width: 31%; font-weight: bold;" data-ng-style="::{'font-weight' : match.awayTeam === dtc.$scope.teamname ? 'bold' : ''}" class="ng-binding">Arsenal</td></tr>
from selenium import webdriver
website='https://www.adamchoi.co.uk/overs/detailed'
path="C:\chromedriver.exe"
driver=webdriver.Chrome(path)
driver.get(website)
all_matches_button=driver.find_element_by_xpath('//label[@analytics-event="All matches"]')
all_matches_button.click()
#SEACHING OR EXTRACTING THE ELEMENTS BY TAG-NAME.
#tr tag name given to all elements in a particular row.
matches = driver.find_elements_by_tag_name('tr')
for match in matches:
    print(match.text) #returns text of each element of matches row by row.
# Out:
# 13-08-2021 Brentford 2 - 0 Arsenal
# 22-08-2021 Arsenal 0 - 2 Chelsea
# 28-08-2021 Man City 5 - 0 Arsenal
# 11-09-2021 Arsenal 1 - 0 Norwich
# 18-09-2021 Burnley 0 - 1 Arsenal
# 26-09-2021 Arsenal 3 - 1 Tottenham
# 02-10-2021 Brighton 0 - 0 Arsenal
# 18-10-2021 Arsenal 2 - 2 Crystal Palace
# 22-10-2021 Arsenal 3 - 1 Aston Villa
# 30-10-2021 Leicester 0 - 2 Arsenal
# 07-11-2021 Arsenal 1 - 0 Watford
# 20-11-2021 Liverpool 4 - 0 Arsenal
# 27-11-2021 Arsenal 2 - 0 Newcastle
# 02-12-2021 Man United 3 - 2 Arsenal
# 06-12-2021 Everton 2 - 1 Arsenal
# 11-12-2021 Arsenal 3 - 0 Southampton
# 15-12-2021 Arsenal 2 - 0 West Ham
# 18-12-2021 Leeds 1 - 4 Arsenal
# 26-12-2021 Norwich 0 - 5 Arsenal
# 01-01-2022 Arsenal 1 - 2 Man City
# 23-01-2022 Arsenal 0 - 0 Burnley
# 10-02-2022 Wolves 0 - 1 Arsenal
# 19-02-2022 Arsenal 2 - 1 Brentford
# 24-02-2022 Arsenal 2 - 1 Wolves
# 06-03-2022 Watford 2 - 3 Arsenal
# 13-03-2022 Arsenal 2 - 0 Leicester
# 16-03-2022 Arsenal 0 - 2 Liverpool
# ...

# %%
#EXTRACTING DATA FROM TABLE.
#for Table using using same method of using arrow and loacating a row together using elements.
#eg for selecting first row fully we have html code in site as--
#<tr data-ng-repeat="match in ::dtc.$scope.matches" data-ng-class=":refreshHighlight:match.result === ' - ' ? 'upcoming' : dtc.getHighlight(match, match.homeTeam === dtc.$scope.teamname ? 'home' : 'away')" class="ng-scope isNotHighlightedRow"><td style="width:25%;" class="ng-binding">13-08-2021</td><td style="width:31%;" data-ng-style="::{'font-weight' : match.homeTeam === dtc.$scope.teamname ? 'bold' : ''}" class="ng-binding">Brentford</td><td style="width:13%;" class="ng-binding">2 - 0</td><td style="width: 31%; font-weight: bold;" data-ng-style="::{'font-weight' : match.awayTeam === dtc.$scope.teamname ? 'bold' : ''}" class="ng-binding">Arsenal</td></tr>
from selenium import webdriver
website='https://www.adamchoi.co.uk/overs/detailed'
path="C:\chromedriver.exe"
driver=webdriver.Chrome(path)
driver.get(website)
all_matches_button=driver.find_element_by_xpath('//label[@analytics-event="All matches"]')
all_matches_button.click()
#SEACHING OR EXTRACTING THE ELEMENTS BY TAG-NAME.
#tr tag name given to all elements in a particular row.
matches = driver.find_elements_by_tag_name('tr')
#empty list initially to store data.
date=[]
home_team=[]
score=[]
away_team=[]
for match in matches:
    #print(match.text) #returns text of each element of matches row by row.
    date.append(match.find_element_by_xpath('./td[1]').text)
    home_team.append(match.find_element_by_xpath('./td[2]').text)
    score.append(match.find_element_by_xpath('./td[3]').text)
    away_team.append(match.find_element_by_xpath('./td[4]').text)
    home=match.find_element_by_xpath('./td[2]').text
    print(home)
#. used to find current context or present node.
#actually we have for 1 st column x-path expression //tr/td[1] 
#where tr represents table as in matches = driver.find_elements_by_tag_name('tr')
#Above we used ./td where . replaces tr tag or matches = driver.find_elements_by_tag_name('tr')
#and after this we write td tag .i.e td[1] or any req td column tag.
#//tr used to represent table.
#//tr/td used to represent elements inside the table.
#//tr/td[1] used to represent elements in the first column.
#//tr/td[2] used to represent elements in the second column.
#//tr/td[3] used to represent elements in the third column.
# Out:
# Brentford
# Arsenal
# Man City
# Arsenal
# Burnley
# Arsenal
# Brighton
# Arsenal
# Arsenal
# Leicester
# Arsenal
# Liverpool
# Arsenal
# Man United
# Everton
# Arsenal
# Arsenal
# Leeds
# Norwich
# Arsenal
# Arsenal
# Wolves
# Arsenal
# Arsenal
# Watford
# Arsenal
# Arsenal
# Aston Villa
# Crystal Palace
# Arsenal
# Southampton
# Chelsea
# Arsenal
# West Ham
# Arsenal
# Tottenham
# Newcastle
# Arsenal
# Watford
# Aston Villa
# Aston Villa
# Chelsea
# Aston Villa
# Man United
# Tottenham
# Aston Villa
# Arsenal
# Aston Villa
# Southampton
# Aston Villa
# Crystal Palace
# Aston Villa
# Aston Villa
# Liverpool
# Norwich
# Aston Villa
# Brentford
# Aston Villa
# Everton
# Aston Villa
# Newcastle
# Aston Villa
# Brighton
# Aston Villa
# Leeds
# West Ham
# Aston Villa
# Wolves
# Aston Villa
# Leicester
# Aston Villa
# Burnley
# Aston Villa
# Aston Villa
# Aston Villa
# Man City
# Brentford
# Crystal Palace
# Aston Villa
# Brentford
# Wolves
# Brentford
# West Ham
# Brentford
# Brentford
# ...

# %%
#EXTRACTING DATA FROM TABLE.
#for Table using using same method of using arrow and loacating a row together using elements.
#eg for selecting first row fully we have html code in site as--
#<tr data-ng-repeat="match in ::dtc.$scope.matches" data-ng-class=":refreshHighlight:match.result === ' - ' ? 'upcoming' : dtc.getHighlight(match, match.homeTeam === dtc.$scope.teamname ? 'home' : 'away')" class="ng-scope isNotHighlightedRow"><td style="width:25%;" class="ng-binding">13-08-2021</td><td style="width:31%;" data-ng-style="::{'font-weight' : match.homeTeam === dtc.$scope.teamname ? 'bold' : ''}" class="ng-binding">Brentford</td><td style="width:13%;" class="ng-binding">2 - 0</td><td style="width: 31%; font-weight: bold;" data-ng-style="::{'font-weight' : match.awayTeam === dtc.$scope.teamname ? 'bold' : ''}" class="ng-binding">Arsenal</td></tr>
from selenium import webdriver
website='https://www.adamchoi.co.uk/overs/detailed'
path="C:\chromedriver.exe"
driver=webdriver.Chrome(path)
driver.get(website)
all_matches_button=driver.find_element_by_xpath('//label[@analytics-event="All matches"]')
all_matches_button.click()
#SEACHING OR EXTRACTING THE ELEMENTS BY TAG-NAME.
#tr tag name given to all elements in a particular row.
matches = driver.find_elements_by_tag_name('tr')
#empty list initially to store data.
date=[]
home_team=[]
score=[]
away_team=[]
for match in matches:
    #print(match.text) #returns text of each element of matches row by row.
    date.append(match.find_element_by_xpath('./td[1]').text)
    home_team.append(match.find_element_by_xpath('./td[2]').text)
    score.append(match.find_element_by_xpath('./td[3]').text)
    away_team.append(match.find_element_by_xpath('./td[4]').text)
    home=match.find_element_by_xpath('./td[2]').text
    print(home)
#. used to find current context or present node.
#actually we have for 1 st column x-path expression //tr/td[1] 
#where tr represents table as in matches = driver.find_elements_by_tag_name('tr')
#Above we used ./td where . replaces tr tag or matches = driver.find_elements_by_tag_name('tr')
#and after this we write td tag .i.e td[1] or any req td column tag.
#//tr used to represent table.
#//tr/td used to represent elements inside the table.
#//tr/td[1] used to represent elements in the first column.
#//tr/td[2] used to represent elements in the second column.
#//tr/td[3] used to represent elements in the third column.

# %%
#EXPORTING DATA TO CSV FILE USING PANDAS.
#for Table using using same method of using arrow and loacating a row together using elements.
#eg for selecting first row fully we have html code in site as--
#<tr data-ng-repeat="match in ::dtc.$scope.matches" data-ng-class=":refreshHighlight:match.result === ' - ' ? 'upcoming' : dtc.getHighlight(match, match.homeTeam === dtc.$scope.teamname ? 'home' : 'away')" class="ng-scope isNotHighlightedRow"><td style="width:25%;" class="ng-binding">13-08-2021</td><td style="width:31%;" data-ng-style="::{'font-weight' : match.homeTeam === dtc.$scope.teamname ? 'bold' : ''}" class="ng-binding">Brentford</td><td style="width:13%;" class="ng-binding">2 - 0</td><td style="width: 31%; font-weight: bold;" data-ng-style="::{'font-weight' : match.awayTeam === dtc.$scope.teamname ? 'bold' : ''}" class="ng-binding">Arsenal</td></tr>
from selenium import webdriver
import pandas as pd
website='https://www.adamchoi.co.uk/overs/detailed'
path="C:\chromedriver.exe"
driver=webdriver.Chrome(path)
driver.get(website)
all_matches_button=driver.find_element_by_xpath('//label[@analytics-event="All matches"]')
all_matches_button.click()
#SEACHING OR EXTRACTING THE ELEMENTS BY TAG-NAME.
#tr tag name given to all elements in a particular row.
matches = driver.find_elements_by_tag_name('tr')
#empty list initially to store data.
date=[]
home_team=[]
score=[]
away_team=[]
for match in matches:
    #print(match.text) #returns text of each element of matches row by row.
    date.append(match.find_element_by_xpath('./td[1]').text)
    home_team.append(match.find_element_by_xpath('./td[2]').text)
    score.append(match.find_element_by_xpath('./td[3]').text)
    away_team.append(match.find_element_by_xpath('./td[4]').text)
    #home=match.find_element_by_xpath('./td[2]').text
    #print(home)
#. used to find current context or present node.
#actually we have for 1 st column x-path expression //tr/td[1] 
#where tr represents table as in matches = driver.find_elements_by_tag_name('tr')
#Above we used ./td where . replaces tr tag or matches = driver.find_elements_by_tag_name('tr')
#and after this we write td tag .i.e td[1] or any req td column tag.
#//tr used to represent table.
#//tr/td used to represent elements inside the table.
#//tr/td[1] used to represent elements in the first column.
#//tr/td[2] used to represent elements in the second column.
#//tr/td[3] used to represent elements in the third column.
driver.quit()
df = pd.DataFrame({'date':date,'home_team':home_team,'score':score,'away_team':away_team})
df.to_csv('football_data.csv',index=False)
print(df)
# Out:
#            date  home_team  score away_team
# 0    13-08-2021  Brentford  2 - 0   Arsenal
# 1    22-08-2021    Arsenal  0 - 2   Chelsea
# 2    28-08-2021   Man City  5 - 0   Arsenal
# 3    11-09-2021    Arsenal  1 - 0   Norwich
# 4    18-09-2021    Burnley  0 - 1   Arsenal
# ..          ...        ...    ...       ...
# 755  30-04-2022     Wolves  0 - 3  Brighton
# 756  07-05-2022    Chelsea  2 - 2    Wolves
# 757  11-05-2022     Wolves  1 - 5  Man City
# 758  15-05-2022     Wolves  1 - 1   Norwich
# 759  22-05-2022  Liverpool  3 - 1    Wolves
#
# [760 rows x 4 columns]

# %%
#SELECTING ELEMENTS WITHIN A DROPDOWN AND THEN STORE IN CSV.
from selenium import webdriver
import pandas as pd
from selenium.webdriver.support.ui import Select
import time
website='https://www.adamchoi.co.uk/overs/detailed'
path="C:\chromedriver.exe"
driver=webdriver.Chrome(path)
driver.get(website)
all_matches_button=driver.find_element_by_xpath('//label[@analytics-event="All matches"]')
all_matches_button.click()
#for dropdown select country having id country we use Select.
dropdown = Select(driver.find_element_by_id('country'))
dropdown.select_by_visible_text('Spain') #used visible text of dropdown menu 
#above we could also use select_by_index where we provide index 0, 1 or 2 and so on based on the requirement.
time.sleep(3)
#above line for code to wait for 3 seconds before executing next line of code.
#SEACHING OR EXTRACTING THE ELEMENTS BY TAG-NAME.
#tr tag name given to all elements in a particular row.
matches = driver.find_elements_by_tag_name('tr')
#empty list initially to store data.
date=[]
home_team=[]
score=[]
away_team=[]
for match in matches:
    #print(match.text) #returns text of each element of matches row by row.
    date.append(match.find_element_by_xpath('./td[1]').text)
    home_team.append(match.find_element_by_xpath('./td[2]').text)
    score.append(match.find_element_by_xpath('./td[3]').text)
    away_team.append(match.find_element_by_xpath('./td[4]').text)
    #home=match.find_element_by_xpath('./td[2]').text
    #print(home)
#. used to find current context or present node.
#actually we have for 1 st column x-path expression //tr/td[1] 
#where tr represents table as in matches = driver.find_elements_by_tag_name('tr')
#Above we used ./td where . replaces tr tag or matches = driver.find_elements_by_tag_name('tr')
#and after this we write td tag .i.e td[1] or any req td column tag.
#//tr used to represent table.
#//tr/td used to represent elements inside the table.
#//tr/td[1] used to represent elements in the first column.
#//tr/td[2] used to represent elements in the second column.
#//tr/td[3] used to represent elements in the third column.
driver.quit()
df = pd.DataFrame({'date':date,'home_team':home_team,'score':score,'away_team':away_team})
df.to_csv('Spain_football_data.csv',index=False)
print(df)
# Out:
#            date   home_team  score    away_team
# 0    14-08-2021      Alaves  1 - 4  Real Madrid
# 1    21-08-2021      Alaves  0 - 1     Mallorca
# 2    27-08-2021    Valencia  3 - 0       Alaves
# 3    18-09-2021      Alaves  0 - 2      Osasuna
# 4    22-09-2021     Espanol  1 - 0       Alaves
# ..          ...         ...    ...          ...
# 755  30-04-2022      Alaves  2 - 1   Villarreal
# 756  08-05-2022  Villarreal  1 - 1      Sevilla
# 757  12-05-2022   Vallecano  1 - 5   Villarreal
# 758  15-05-2022  Villarreal  1 - 2     Sociedad
# 759  22-05-2022   Barcelona  0 - 2   Villarreal
#
# [760 rows x 4 columns]
