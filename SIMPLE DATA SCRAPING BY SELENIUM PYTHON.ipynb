# %%
from selenium import webdriver
driver = webdriver.Chrome("C:\chromedriver.exe")
driver.get('https://www.selenium.dev/documentation/')#to get the above link or to open the above link.
driver.close()#to close the driver.

# %%
from selenium import webdriver
driver = webdriver.Chrome("C:\chromedriver.exe")
driver.get('https://www.selenium.dev/documentation/')#to get the above link or to open the above link.
#title = driver.find_element_by_xpath('//h1[@id or class ="something"]').text
#print(title)
##to locate an id or class that contains data to be printed i. of form <h1 id="something">---</h1>
driver.close()#to close the driver.

# %%
from selenium import webdriver
driver = webdriver.Chrome("C:\chromedriver.exe")
driver.get('https://www.google.com/search?q=donald+trump&sxsrf=ALiCzsaJjnVQ5n64nI4ntdCgNBQ5fQ8EPQ%3A1656691344835&ei=kBq_YqnXMsyfseMP7uK38AU&ved=0ahUKEwip3_GYiNj4AhXMT2wGHW7xDV4Q4dUDCA4&uact=5&oq=donald+trump&gs_lcp=-gNYnhZguxpoAXABeACAAcEBiAHfDpIBBDAuMTKYAQCgAQGwAQrAAQE&sclient=gws-wiz')#to get the above link or to open the above link.
title = driver.find_element_by_xpath('//h3[@class ="LC20lb MBeuO DKV0Md"]').text
print(title)
driver.close()#to close the driver.
# Out:
# Donald Trump - Wikipedia

# %%
from selenium import webdriver
driver = webdriver.Chrome("C:\chromedriver.exe")
driver.get('https://www.google.com/search?q=donald+trump&sxsrf=ALiCzsaJjnVQ5n64nI4ntdCgNBQ5fQ8EPQ%3A1656691344835&ei=kBq_YqnXMsyfseMP7uK38AU&ved=0ahUKEwip3_GYiNj4AhXMT2wGHW7xDV4Q4dUDCA4&uact=5&oq=donald+trump&gs_lcp=-gNYnhZguxpoAXABeACAAcEBiAHfDpIBBDAuMTKYAQCgAQGwAQrAAQE&sclient=gws-wiz')#to get the above link or to open the above link.
titlet = driver.find_element_by_xpath('//div[@class ="GLI8Bc"]').text
print(titlet)
driver.close()#to close the driver.
# Out:
# Donald Trump - Wikipedia
# https://en.wikipedia.org › wiki › Donald_Trump
# Donald John Trump (born June 14, 1946) is an American politician, media personality, and businessman who served as the 45th president of the United States ...
# Vice President: Mike Pence
# Parent(s): Fred Trump; Mary Anne MacLeod
# Occupation: Politician; businessman; media p...
# Residence(s): Palm Beach, Florida
# Trump Jr · Donald Trump (disambiguation) · Bibliography of Donald Trump · Family

# %%
from selenium import webdriver
driver = webdriver.Chrome("C:\chromedriver.exe")
driver.get('https://www.google.com/search?q=donald+trump&sxsrf=ALiCzsaJjnVQ5n64nI4ntdCgNBQ5fQ8EPQ%3A1656691344835&ei=kBq_YqnXMsyfseMP7uK38AU&ved=0ahUKEwip3_GYiNj4AhXMT2wGHW7xDV4Q4dUDCA4&uact=5&oq=donald+trump&gs_lcp=-gNYnhZguxpoAXABeACAAcEBiAHfDpIBBDAuMTKYAQCgAQGwAQrAAQE&sclient=gws-wiz')#to get the above link or to open the above link.
title = driver.find_element_by_xpath('//div[@class ="aUSklf"]').text
print(title)
driver.close()#to close the driver.
# Out:
# Promotional Tweet From Former Trump Lawyer Rudy Giuliani Shocks Internet
# 9 hours ago
# Trump tried to grab limo steering wheel, wanted to join Jan 6 Capitol riot, aide testifies
# 1 day ago
# The Indian Express
# Explained: Who is Cassidy Hutchinson, Trump's former staff member?
# 1 day ago
# US Supreme Court Allows Biden To End Trump-Era Immigration Rule
# 23 hours ago

# %%
from selenium import webdriver
driver = webdriver.Chrome("C:\chromedriver.exe")
driver.get('https://www.google.com/search?q=donald+trump&sxsrf=ALiCzsaJjnVQ5n64nI4ntdCgNBQ5fQ8EPQ%3A1656691344835&ei=kBq_YqnXMsyfseMP7uK38AU&ved=0ahUKEwip3_GYiNj4AhXMT2wGHW7xDV4Q4dUDCA4&uact=5&oq=donald+trump&gs_lcp=-gNYnhZguxpoAXABeACAAcEBiAHfDpIBBDAuMTKYAQCgAQGwAQrAAQE&sclient=gws-wiz')#to get the above link or to open the above link.
whole1 = driver.find_element_by_xpath('//div[@class ="s6JM6d"]').text
print(whole1)
driver.close()#to close the driver.
# Out:
# Search Results
# Top stories
# Promotional Tweet From Former Trump Lawyer Rudy Giuliani Shocks Internet
# 9 hours ago
# Elon Musk's tweets echo tactics used to great effect by Donald Trump
# 1 day ago
# The Indian Express
# Explained: Who is Cassidy Hutchinson, Trump's former staff member?
# 1 day ago
# US Supreme Court Allows Biden To End Trump-Era Immigration Rule
# 23 hours ago
# More news
#
# Donald Trump - Wikipedia
# https://en.wikipedia.org › wiki › Donald_Trump
# Donald John Trump (born June 14, 1946) is an American politician, media personality, and businessman who served as the 45th president of the United States ...
# Vice President: Mike Pence
# Parent(s): Fred Trump; Mary Anne MacLeod
# Occupation: Politician; businessman; media p...
# Residence(s): Palm Beach, Florida
# Trump Jr · Donald Trump (disambiguation) · Bibliography of Donald Trump · Family
# Twitter results
# Donald Trump Jr. (@DonaldJTrumpJr) · Twitter
# https://twitter.com/DonaldJTrumpJr
# ...

# %%
from selenium import webdriver
driver = webdriver.Chrome("C:\chromedriver.exe")
driver.get('https://www.google.com/search?q=donald+trump&sxsrf=ALiCzsaJjnVQ5n64nI4ntdCgNBQ5fQ8EPQ%3A1656691344835&ei=kBq_YqnXMsyfseMP7uK38AU&ved=0ahUKEwip3_GYiNj4AhXMT2wGHW7xDV4Q4dUDCA4&uact=5&oq=donald+trump&gs_lcp=-gNYnhZguxpoAXABeACAAcEBiAHfDpIBBDAuMTKYAQCgAQGwAQrAAQE&sclient=gws-wiz')#to get the above link or to open the above link.
whole2 = driver.find_element_by_xpath('//div[@class ="GyAeWb"]').text
print(whole2)
driver.close()#to close the driver.
# Out:
# Search Results
# Top stories
# Promotional Tweet From Former Trump Lawyer Rudy Giuliani Shocks Internet
# 9 hours ago
# Elon Musk's tweets echo tactics used to great effect by Donald Trump
# 1 day ago
# The Indian Express
# Explained: Who is Cassidy Hutchinson, Trump's former staff member?
# 1 day ago
# US Supreme Court Allows Biden To End Trump-Era Immigration Rule
# 23 hours ago
# More news
#
# Donald Trump - Wikipedia
# https://en.wikipedia.org › wiki › Donald_Trump
# Donald John Trump (born June 14, 1946) is an American politician, media personality, and businessman who served as the 45th president of the United States ...
# Vice President: Mike Pence
# Occupation: Politician; businessman; media p...
# Alma mater: Wharton School (BS Econ.)
# Parent(s): Fred Trump; Mary Anne MacLeod
# Trump Jr · Donald Trump (disambiguation) · Bibliography of Donald Trump · Family
# Twitter results
# Donald Trump Jr. (@DonaldJTrumpJr) · Twitter
# https://twitter.com/DonaldJTrumpJr
# ...

# %%
from selenium import webdriver
driver = webdriver.Chrome("C:\chromedriver.exe")
driver.get('https://www.google.com/search?q=donald+trump&sxsrf=ALiCzsaJjnVQ5n64nI4ntdCgNBQ5fQ8EPQ%3A1656691344835&ei=kBq_YqnXMsyfseMP7uK38AU&ved=0ahUKEwip3_GYiNj4AhXMT2wGHW7xDV4Q4dUDCA4&uact=5&oq=donald+trump&gs_lcp=-gNYnhZguxpoAXABeACAAcEBiAHfDpIBBDAuMTKYAQCgAQGwAQrAAQE&sclient=gws-wiz')#to get the above link or to open the above link.
link = driver.find_element_by_xpath('//div[@class ="yuRUbf"]/a').get_attribute('href')
print(link)
driver.close()#to close the driver.
# Out:
# https://en.wikipedia.org/wiki/Donald_Trump

# %%
from selenium import webdriver
driver = webdriver.Chrome("C:\chromedriver.exe")
driver.get('https://www.google.com/search?q=donald+trump&sxsrf=ALiCzsaJjnVQ5n64nI4ntdCgNBQ5fQ8EPQ%3A1656691344835&ei=kBq_YqnXMsyfseMP7uK38AU&ved=0ahUKEwip3_GYiNj4AhXMT2wGHW7xDV4Q4dUDCA4&uact=5&oq=donald+trump&gs_lcp=-gNYnhZguxpoAXABeACAAcEBiAHfDpIBBDAuMTKYAQCgAQGwAQrAAQE&sclient=gws-wiz')#to get the above link or to open the above link.
detail = driver.find_element_by_xpath('//div[@class ="VwiC3b yXK7lf MUxGbd yDYNvb lyLwlc"]').text
print(detail)
driver.close()#to close the driver.
# Out:
# Donald John Trump (born June 14, 1946) is an American politician, media personality, and businessman who served as the 45th president of the United States ...
